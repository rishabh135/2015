# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabh135/2015/blob/master/webdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install datasets

# %%
import datasets
from pprint import pprint

# %%
cc = datasets.load_dataset('pixparse/cc12m-wds', streaming=True)
cc = cc.shuffle()
pprint(cc['train'].features)
cursor = iter(cc['train'])
# Out:
# Resolving data files:   0%|          | 0/2176 [00:00<?, ?it/s]
# {'__key__': Value(dtype='string', id=None),
#  '__url__': Value(dtype='string', id=None),
#  'jpg': Image(decode=True, id=None),
#  'json': {'caption': Value(dtype='string', id=None),
#           'error_message': Value(dtype='null', id=None),
#           'exif': Value(dtype='string', id=None),
#           'height': Value(dtype='int64', id=None),
#           'key': Value(dtype='string', id=None),
#           'original_height': Value(dtype='int64', id=None),
#           'original_width': Value(dtype='int64', id=None),
#           'status': Value(dtype='string', id=None),
#           'url': Value(dtype='string', id=None),
#           'width': Value(dtype='int64', id=None)},
#  'txt': Value(dtype='string', id=None)}

# %%
sample = next(cursor)
print(sample['txt'])
sample['jpg']
# Out:
# Adventure Time Finn the Human Custom Bricks Anime Series Not Lego
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=520x512>

# %%
sample = next(cursor)
print(sample['txt'])
sample['jpg']
# Out:
# The floor plan of My Athens Diamond!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x512>
